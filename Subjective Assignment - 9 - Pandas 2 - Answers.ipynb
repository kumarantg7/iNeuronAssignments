# %% [markdown]
# # Assignment

# %% [markdown]
# Link for Datasets
# (https://drive.google.com/drive/folders/105ftuIwN9kqyPNEEm3E6IM7LqywjyvJa?usp=sharing)

# %% [markdown]
# Q21. Write a pandas program to import three datasheets from a given
# excel data (coalpublic2013.xlsx ) in to a single dataframe.
#
# Note: Structure of three datasheets are same.

# %%
#Only one sheet in coalpublic2013.xlsx so using employee.xlsx
import pandas as pd
df_sheet1 = pd.read_excel("H:\Downloads\INeuron Deep Learning\Assignments\Data sets\employee.xlsx", sheet_name = 0)
df_sheet2 = pd.read_excel("H:\Downloads\INeuron Deep Learning\Assignments\Data sets\employee.xlsx", sheet_name = 1)
df_sheet3 = pd.read_excel("H:\Downloads\INeuron Deep Learning\Assignments\Data sets\employee.xlsx", sheet_name = 2)
df_book = pd.concat([df_sheet1, df_sheet2, df_sheet3], ignore_index=True)
df_book
# Out:
#     emp_id   first_name    last_name  hire_date
# 0      100       Steven         King 2003-06-17
# 1      101        Neena      Kochhar 2005-09-21
# 2      102          Lex      De Haan 2001-01-13
# 3      103    Alexander       Hunold 2006-01-03
# 4      104        Bruce        Ernst 2007-05-21
# 5      105        David       Austin 2005-06-25
# 6      106        Valli    Pataballa 2006-02-05
# 7      107        Diana      Lorentz 2007-02-07
# 8      108        Nancy    Greenberg 2002-08-17
# 9      109       Daniel       Faviet 2002-08-16
# 10     110         John         Chen 2005-09-28
# 11     111       Ismael      Sciarra 2005-09-30
# 12     112  Jose Manuel        Urman 2006-03-07
# 13     113         Luis         Popp 2007-12-07
# 14     114          Den     Raphaely 2002-12-07
# 15     115    Alexander         Khoo 2003-05-18
# 16     116       Shelli        Baida 2005-12-24
# 17     117        Sigal       Tobias 2005-07-24
# 18     118          Guy       Himuro 2006-11-15
# ...

# %% [markdown]
# Q 22. Write a pandas program to import three datasheets from a given
# excel data (employee.xlsx ) into a single data frame and export the
# result into new Excel file.
#
# Note: Structure of three datasheets are same.

# %%
#Only one sheet in coalpublic2013.xlsx so using employee.xlsx
from openpyxl.workbook import Workbook
import pandas as pd
df_sheet1 = pd.read_excel("H:\Downloads\INeuron Deep Learning\Assignments\Data sets\employee.xlsx", sheet_name = 0)
df_sheet2 = pd.read_excel("H:\Downloads\INeuron Deep Learning\Assignments\Data sets\employee.xlsx", sheet_name = 1)
df_sheet3 = pd.read_excel("H:\Downloads\INeuron Deep Learning\Assignments\Data sets\employee.xlsx", sheet_name = 2)
df_book = pd.concat([df_sheet1, df_sheet2, df_sheet3], ignore_index=True)
df_book.to_excel("H:\Downloads\INeuron Deep Learning\Assignments\Data sets\Consolidated_employee.xlsx", sheet_name='final', index=False)
print("Consolidated file saved successfully.")
# Out:
# Consolidated file saved successfully.

# %% [markdown]
# Q23. Write a pandas program to create the Pivot table with multiple
# indexes from the data set of the titanic.csv.

# %%
import numpy as np
file = r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\titanic.csv'
df_csv = pd.read_csv(file)
pivot_excel = pd.pivot_table(df_csv, index = ["who","class"], values=['survived'], aggfunc=np.sum)
pivot_excel
# Out:
#               survived
# who   class
# child First          5
#       Second        19
#       Third         25
# man   First         42
#       Second         8
#       Third         38
# woman First         89
#       Second        60
#       Third         56

# %% [markdown]
# Q24. Write a Pandas program to create the Pivot table and find survival
# rate by gender?

# %%
import numpy as np
file = r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\titanic.csv'
df_csv = pd.read_csv(file)
pivot_total = pd.pivot_table(df_csv, index = ["sex"], values=['survived'])
pivot_total
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %% [markdown]
# Q25. Write a pandas program to make partition each of the passengers
# into 4 categories based on their age.
#
# Note: Age categories- (0, 10), (10, 30), (30, 60), (60, 80)

# %%
df_csv = pd.read_csv(r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\titanic.csv')
df_age_range = pd.cut(df_csv['age'], [0, 10, 30, 60, 80])
df_age_range
# Out:
# 0      (10.0, 30.0]
# 1      (30.0, 60.0]
# 2      (10.0, 30.0]
# 3      (30.0, 60.0]
# 4      (30.0, 60.0]
#            ...
# 886    (10.0, 30.0]
# 887    (10.0, 30.0]
# 888             NaN
# 889    (10.0, 30.0]
# 890    (30.0, 60.0]
# Name: age, Length: 891, dtype: category
# Categories (4, interval[int64]): [(0, 10] < (10, 30] < (30, 60] < (60, 80]]

# %% [markdown]
# Q26. Write a pandas program to create the Pivot table and find survival
# rate by the gender, age of the different categories of various
# classes.

# %%
import numpy as np
file = r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\titanic.csv'
df_csv = pd.read_csv(file)
df_csv['age'] = pd.cut(df_csv['age'], [0, 10, 30, 60, 80])
pivot_total = pd.pivot_table(df_csv, index = ["sex",'age'], columns='class', values=['survived'])
pivot_total
# Out:
#                  survived
# class               First    Second     Third
# sex    age
# female (0, 10]   0.000000  1.000000  0.500000
#        (10, 30]  0.970588  0.916667  0.508772
#        (30, 60]  0.979167  0.900000  0.272727
#        (60, 80]  1.000000       NaN  1.000000
# male   (0, 10]   1.000000  1.000000  0.363636
#        (10, 30]  0.458333  0.023256  0.139073
#        (30, 60]  0.412698  0.090909  0.118421
#        (60, 80]  0.083333  0.333333  0.000000

# %% [markdown]
# Q27. Write a pandas program to create the Pivot table and calculate
# number of women and men were in a particular cabin class.

# %%
import numpy as np
file = r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\titanic.csv'
df_csv = pd.read_csv(file)
df_csv['count'] = list(range(1,len(df_csv.index)+1))
pivot_total = pd.pivot_table(df_csv, index = ["sex"], columns='class', values=['count'], aggfunc='count')
pivot_total
# Out:
#        count
# class  First Second Third
# sex
# female    94     76   144
# male     122    108   347

# %% [markdown]
# Q28. Write a pandas program to create the Pivot table and separate
# the gender according to whether they travelled alone or not to get
# the probability of survival

# %%
import numpy as np
file = r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\titanic.csv'
df_csv = pd.read_csv(file)
pivot_total = pd.pivot_table(df_csv, index = ["sex"], columns='alone', values=['survived'], aggfunc='mean')
pivot_total
# Out:
#         survived
# alone      False     True
# sex
# female  0.712766  0.785714
# male    0.271084  0.155718

# %% [markdown]
# Q29. Write a pandas program to create the Pivot table and find the
# probability of survival by class, gender, solo boarding, and the port
# of embarkation.

# %%
import numpy as np
file = r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\titanic.csv'
df_csv = pd.read_csv(file)
pivot_total = pd.pivot_table(df_csv, index = ["sex",'class', 'alone'], columns=['embark_town'], values=['survived'], aggfunc='mean')
pivot_total
# Out:
#                      survived
# embark_town         Cherbourg Queenstown Southampton
# sex    class  alone
# female First  False  1.000000   1.000000    0.941176
#               True   0.944444        NaN    1.000000
#        Second False  1.000000        NaN    0.923077
#               True   1.000000   1.000000    0.892857
#        Third  False  0.611111   0.625000    0.327586
#               True   0.800000   0.760000    0.466667
# male   First  False  0.473684   0.000000    0.407407
#               True   0.347826        NaN    0.326923
#        Second False  0.166667        NaN    0.300000
#               True   0.250000   0.000000    0.089552
#        Third  False  0.500000   0.100000    0.142857
#               True   0.151515   0.068966    0.123762

# %% [markdown]
# Q30. Write a pandas program to get current date, oldest date and
# number of days between Current date and the oldest date of Ufo
# dataset.

# %%
df_csv = pd.read_csv(r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\UFO.csv', low_memory=False)
df_csv['datetime'] = pd.to_datetime(df_csv['datetime'], errors='coerce')
df_csv = df_csv.dropna()
print("The current date is: ", df_csv['datetime'].max())
print("The oldest date is: ", df_csv['datetime'].min())
print("Number of days between Current date and the oldest date of Ufo dataset is : ", (df_csv['datetime'].max() - df_csv['datetime'].min()).days)
# Out:
# The current date is:  2014-05-08 00:00:00
# The oldest date is:  1910-06-01 15:00:00
# Number of days between Current date and the oldest date of Ufo dataset is :  37961

# %% [markdown]
# Q31. Write a pandas program to get all sighting days of the
# unidentified flying object (ufo) between 1950-10-10 and 1960-10-
# 10.

# %%
df_csv = pd.read_csv(r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\UFO.csv', low_memory=False)
df_csv['datetime'] = pd.to_datetime(df_csv['datetime'], errors='coerce')
df_csv = df_csv.dropna()
output = df_csv[(df_csv['datetime'] >= pd.to_datetime('1950-10-10')) & (df_csv['datetime'] <= pd.to_datetime('1960-10-10'))]
output
# Out:
#                  datetime             city state country      shape duration (seconds) duration (hours/min)                                                                                                                                        comments date posted    latitude  longitude
# 3     1956-10-10 21:00:00             edna    tx      us     circle                 20             1/2 hour      My older brother and twin sister were leaving the only Edna theater at about 9 PM&#44...we had our bikes and I took a different route home   1/17/2004  28.9783333  -96.645833
# 481   1952-10-01 12:00:00      kansas city    mo      us       disk                 90              90 sec.                                                                                           1952 daylight sighting of multiple discs in formation  10/31/2008  39.0997222  -94.578333
# ...

# %% [markdown]
# Q32. Write a Pandas program to extract the year, month, day, hour,
# minute, second, and weekday from unidentified flying object (UFO)
# reporting date.

# %%
df_csv = pd.read_csv(r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\UFO.csv', low_memory=False)
df_csv['datetime'] = pd.to_datetime(df_csv['datetime'], errors='coerce')
df_csv = df_csv.dropna()
print("Original Dataframe:")
print(df_csv.head())
print("\nYear:")
print(df_csv.datetime.dt.year.head())
print("\nMonth:")
print(df_csv.datetime.dt.month.head())
print("\nDay:")
print(df_csv.datetime.dt.day.head())
print("\nHour:")
print(df_csv.datetime.dt.hour.head())
print("\nMinute:")
print(df_csv.datetime.dt.minute.head())
print("\nSecond:")
print(df_csv.datetime.dt.second.head())
print("\nWeekday:")
print(df_csv.datetime.dt.weekday.head())
# Out:
# Original Dataframe:
#              datetime        city state country     shape duration (seconds) duration (hours/min)                                                                                                                                                    comments date posted    latitude  longitude
# 0 1949-10-10 20:30:00  san marcos    tx      us  cylinder               2700           45 minutes                     This event took place in early fall around 1949-50. It occurred after a Boy Scout meeting in the Baptist Church. The Baptist Church sit   4/27/2004  29.8830556  -97.941111
# 3 1956-10-10 21:00:00        edna    tx      us    circle                 20             1/2 hour                  My older brother and twin sister were leaving the only Edna theater at about 9 PM&#44...we had our bikes and I took a different route home   1/17/2004  28.9783333  -96.645833
# ...

# %% [markdown]
# Q33. Write a pandas program to count year-country wise frequency of
# reporting dates of the unidentified flying object(UFO).

# %%
df_csv = pd.read_csv(r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\UFO.csv', low_memory=False)
df_csv['datetime'] = pd.to_datetime(df_csv['datetime'], errors='coerce')
df_csv = df_csv.dropna()
df_csv['year'] = df_csv['datetime'].dt.year
data = df_csv.groupby(['year','country']).size()
pd.DataFrame(data = data).rename(columns={0:'No. of Reported'})
# Out:
#               No. of Reported
# year country
# 1910 us                     1
# 1920 us                     1
# 1925 us                     1
# 1929 us                     1
# 1931 us                     2
# ...                       ...
# 2013 us                  5961
# 2014 au                     1
#      ca                    40
#      gb                     1
#      us                  1927
#
# [162 rows x 1 columns]

# %% [markdown]
# Q34. Write a pandas program to get the difference (in days) between
# documented date and reporting date of unidentified flying object
# (UFO).

# %%
df_csv = pd.read_csv(r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\UFO.csv', low_memory=False)
df_csv['datetime'] = pd.to_datetime(df_csv['datetime'], errors='coerce')
df_csv['date posted'] = pd.to_datetime(df_csv['date posted'], errors='coerce')
df_csv = df_csv.dropna().reset_index(drop=True)
df_csv['difference'] = (df_csv['date posted'] - df_csv['datetime']).dt.days
print("Difference (in days) between documented date and reporting date of UFO:")
df_csv.head()
# Out:
# Difference (in days) between documented date and reporting date of UFO:
#              datetime        city state country     shape duration (seconds) duration (hours/min)                                                                                                                                                    comments date posted    latitude  longitude   difference
# 0 1949-10-10 20:30:00  san marcos    tx      us  cylinder               2700           45 minutes                     This event took place in early fall around 1949-50. It occurred after a Boy Scout meeting in the Baptist Church. The Baptist Church sit  2004-04-27  29.8830556  -97.941111       19922
# 1 1956-10-10 21:00:00        edna    tx      us    circle                 20             1/2 hour                  My older brother and twin sister were leaving the only Edna theater at about 9 PM&#44...we had our bikes and I took a different route home  2004-01-17  28.9783333  -96.645833       17264
# ...

# %% [markdown]
# Q35. Write a pandas program to generate sequences of fixedfrequency dates and time spans.

# %%
df_dt = pd.date_range('2018-01-01', periods=12, freq='H')
print("Hourly frequency:")
print(df_dt)
df_dt = pd.date_range('2018-01-01', periods=12, freq='min')
print("\nMinutely frequency:")
print(df_dt)
df_dt = pd.date_range('2018-01-01', periods=12, freq='S')
print("\nSecondly frequency:")
print(df_dt)
df_dt = pd.date_range('2018-01-01', periods=12, freq='2H')
print("nMultiple Hourly frequency:")
print(df_dt)
df_dt = pd.date_range('2018-01-01', periods=12, freq='5min')
print("\nMultiple Minutely frequency:")
print(df_dt)
df_dt = pd.date_range('2018-01-01', periods=12, freq='BQ')
print("\nMultiple Secondly frequency:")
print(df_dt)
df_dt = pd.date_range('2018-01-01', periods=12, freq='w')
print("\nWeekly frequency:")
print(df_dt)
df_dt = pd.date_range('2018-01-01', periods=12, freq='2h20min')
print("\nCombine together day and intraday offsets-1:")
print(df_dt)
df_dt = pd.date_range('2018-01-01', periods=12, freq='1D10U')
print("\nCombine together day and intraday offsets-2:")
print(df_dt)
# Out:
# Hourly frequency:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00', '2018-01-01 02:00:00', '2018-01-01 03:00:00', '2018-01-01 04:00:00', '2018-01-01 05:00:00', '2018-01-01 06:00:00', '2018-01-01 07:00:00', '2018-01-01 08:00:00', '2018-01-01 09:00:00', '2018-01-01 10:00:00', '2018-01-01 11:00:00'], dtype='datetime64[ns]', freq='H')
#
# Minutely frequency:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:01:00', '2018-01-01 00:02:00', '2018-01-01 00:03:00', '2018-01-01 00:04:00', '2018-01-01 00:05:00', '2018-01-01 00:06:00', '2018-01-01 00:07:00', '2018-01-01 00:08:00', '2018-01-01 00:09:00', '2018-01-01 00:10:00', '2018-01-01 00:11:00'], dtype='datetime64[ns]', freq='T')
#
# Secondly frequency:
# ...

# %% [markdown]
# Q36. Write a pandas program to manipulate and convert date times
# with timezone information.

# %%
df_dt = pd.date_range('2018-01-01', periods=3, freq='H')
df_dt = df_dt.tz_localize('UTC')
print("In UTC time zone:\n", df_dt)
print("\nFrom UTC to IST:")
df_dt = df_dt.tz_convert('Asia/Calcutta')
print(df_dt)
# Out:
# In UTC time zone:
#  DatetimeIndex(['2018-01-01 00:00:00+00:00', '2018-01-01 01:00:00+00:00', '2018-01-01 02:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='H')
#
# From UTC to IST:
# DatetimeIndex(['2018-01-01 05:30:00+05:30', '2018-01-01 06:30:00+05:30', '2018-01-01 07:30:00+05:30'], dtype='datetime64[ns, Asia/Calcutta]', freq='H')

# %% [markdown]
# Q37. Write a pandas program to create the graphical analysis of UFO
# (unidentified flying object) Sightings year.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
df_csv = pd.read_csv(r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\UFO.csv', low_memory=False)
df_csv['datetime'] = pd.to_datetime(df_csv['datetime'], errors='coerce')
df_csv = df_csv.dropna()
df_csv['year'] = df_csv['datetime'].dt.year
data = df_csv.groupby(['year']).size()
df_reports = pd.DataFrame(data = data).rename(columns={0:'No. of Reported'})
y = df_reports['No. of Reported']
x = df_reports.index
plt.figure(figsize=(15,8))
plt.xlabel('Year')
plt.ylabel('No. of reported')
plt.title('Year vs No. of reported')
plt.xticks(range(1910, 2021, 5))
plt.yticks(range(0, 7000, 500))
plt.plot(x,y, 'ro-')
plt.show( )

# %% [markdown]
# Q39. Write a pandas program to create a heatmap (rectangular data as
# a colour-encoded matrix) for comparison of top 10 years in
# which (UFO ) was sighted VS each Month.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df_csv = pd.read_csv(r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\UFO.csv', low_memory=False)
df_csv['datetime'] = pd.to_datetime(df_csv['datetime'], errors='coerce')
df = df_csv.dropna()
df['datetime'] = df['datetime'].astype('datetime64[ns]')
most_sightings_years = df['datetime'].dt.year.value_counts().head(10)
def is_top_years(year):
    if year in most_sightings_years.index:
        return year
month_vs_year = df.pivot_table(columns=df['datetime'].dt.month,index=df['datetime'].dt.year.apply(is_top_years),aggfunc='count',values='city')
month_vs_year.columns = month_vs_year.columns.astype(int)
month_vs_year.index = month_vs_year.index.astype(int)
print("\nHeatmap for comparison of the top 10 years in which the UFO was sighted vs each month:")
plt.figure(figsize=(10,8))
ax = sns.heatmap(month_vs_year)
ax.set_xlabel('Month').set_size(20)
ax.set_ylabel('Year').set_size(20)
# Out:
# C:\Users\Vicky\Anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# Heatmap for comparison of the top 10 years in which the UFO was sighted vs each month:

# %% [markdown]
# Q40. Write a pandas program to create a Timewheel of Hour VS Year
# comparison of the top 10 years in which the (UFO) was sighted

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.cm as cm

df_csv = pd.read_csv(r'H:\Downloads\INeuron Deep Learning\Assignments\Data sets\UFO.csv', low_memory=False)
df_csv['datetime'] = pd.to_datetime(df_csv['datetime'], errors='coerce')
df = df_csv.dropna()

most_sightings_years = df['datetime'].dt.year.value_counts().head(10)

def is_top_years(year):
    if year in most_sightings_years.index:
        return year
    
month_vs_year = df.pivot_table(columns=df['datetime'].dt.month,index=df['datetime'].dt.year.apply(is_top_years),aggfunc='count',values='city')

month_vs_year.index = month_vs_year.index.astype(int)
month_vs_year.columns = month_vs_year.columns.astype(int)

print("\nComparison of the top 10 years in which the UFO was sighted vs each month:")

def pie_heatmap(table, cmap='coolwarm_r', vmin=None, vmax=None,inner_r=0.25, pie_args={}):
    n, m = table.shape
    vmin= table.min().min() if vmin is None else vmin
    vmax= table.max().max() if vmax is None else vmax
    
    centre_circle = plt.Circle((0,0),inner_r,edgecolor='black',facecolor='white',fill=True,linewidth=0.25)
    plt.gcf().gca().add_artist(centre_circle)
    norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
    cmapper = cm.ScalarMappable(norm=norm, cmap=cmap)

    for i, (row_name, row) in enumerate(table.iterrows()):
        labels = None if i > 0 else table.columns
        wedges = plt.pie([1] * m,radius=inner_r+float(n-i)/n, colors=[cmapper.to_rgba(x) for x in row.values],
            labels=labels, startangle=90, counterclock=False, wedgeprops={'linewidth':-1}, **pie_args)
        plt.setp(wedges[0], edgecolor='grey',linewidth=1.5)
        wedges = plt.pie([1], radius=inner_r+float(n-i-1)/n, colors=['w'], labels=[row_name], startangle=-90, wedgeprops={'linewidth':0})
        plt.setp(wedges[0], edgecolor='grey',linewidth=1.5)
        
plt.figure(figsize=(8,8))
plt.title("Timewheel of Hour Vs Year",y=1.08,fontsize=30)
pie_heatmap(month_vs_year, inner_r=0.2)
# Out:
# Comparison of the top 10 years in which the UFO was sighted vs each month:

# %% [markdown]
# ## Great Job!
